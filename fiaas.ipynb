# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

loader= PyPDFLoader("ShoeMorph_Research_Paper.pdf")
document=loader.load()
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=50
)
docs=text_splliter.split_documents(document)

# %%
docs
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'TeX', 'creationdate': '2026-03-20T18:18:49+00:00', 'moddate': '2026-03-20T18:18:49+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'trapped': '/False', 'source': 'ShoeMorph_Research_Paper.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='ShoeMorph: Exploring Classical Computer Vision Techniques for\nAsymmetry-Aware Foot Size Estimation\nAkshat Bari 1, Ayush Kumar Maheshwari 2, Himesh Kumar 3\n1,2,3 Department of Computer Science,\n1,2,3 Poornima Institute of Engineering and Technology, Jaipur, India\nEmails: 12022pietcsakshat009@poornima.org, 22022pietcsayush041@poornima.org,\n32022pietcshimesh071@poornima.org\nAbstract\nThe paper introduces a minimalist and explainable computer vision based method to estimate the size\nof human feet along with the required shoe sizes based on a single monocular image, without involving\nthe use of deep
# ...

# %%
embedding=OllamaEmbeddings(model='nomic-embed-text-v2-moe')
db=FAISS.from_documents(docs,embedding)
db
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 embedding=OllamaEmbeddings(model='nomic-embed-text-v2-moe')
# ----> 2 db=FAISS.from_documents(docs,embedding)
#       3 db
#
# File c:\Users\Lenovo\Desktop\langchain\venv\Lib\site-packages\langchain_core\vectorstores\base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\Lenovo\Desktop\langchain\venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
# ...

# %%
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
embedding = OllamaEmbeddings(model="nomic-embed-text-v2-moe")

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=50
)

split_docs = text_splitter.split_documents(docs)

db = FAISS.from_documents(split_docs, embedding)

# %%
query="recognition algorithm and predicted the size of shoes in real time"

# %%
d= db.similarity_search(query)
d[0].page_content
# Out:
# 'utilizing convolutional neural networks (CNNs), 3D reconstruction techniques, and multi-view geometry to\npredict the foot sizes with an extremely high accuracy. Although they are very active, these methods need\nhuge annotated datasets, extensive computational power, and a specific hardware: depth sensors or many'
