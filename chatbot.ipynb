# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = groq_api_key

# %%
groq_api_key
# Out:
# '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'

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.1-8b-instant",groq_api_key="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")
model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000002724360D150>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002724360D9D0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage
response=model.invoke([HumanMessage(content='hey i am himesh and i am an ai engineer')])
response.content
# Out:
# "Nice to meet you, Himesh. As an AI engineer, you must be working on some exciting projects. I'm happy to chat with you about AI, machine learning, or any other related topics. What specific areas of AI engineering are you interested in or working on?"

# %%
from langchain_core.messages import AIMessage
response=model.invoke(
    [
        HumanMessage(content="hey i am himesh and i am an ai engineer"),
        AIMessage(content="Nice to meet you, Himesh. As an AI engineer, you must be working on some exciting projects. I'm happy to chat with you about AI, machine learning, or any other related topics. What specific areas of AI engineering are you interested in or working on?"),
        HumanMessage(content="what is my name and what do i do?")
    ]

)
response.content
# Out:
# 'Your name is Himesh, and you are an AI engineer.'

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
store={}
def get_session_history(session_id:str)->BaseChatMessageHistory:
    if session_id not in store:
        store[session_id]=ChatMessageHistory()
    return store[session_id]

with_message_history=RunnableWithMessageHistory(model,get_session_history)

# %%
config={"configurable":{"session_id":"chat1"}}

# %%
with_message_history.invoke(
    [
        HumanMessage(content="hi i am himesh and i am an ai engineer")
    ],
    config=config
)
# Out:
# AIMessage(content="Hi Himesh, nice to meet you. As an AI engineer, that's really cool. What specific areas of AI are you working on or interested in? Natural Language Processing (NLP), Computer Vision, Reinforcement Learning, or something else?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 46, 'total_tokens': 98, 'completion_time': 0.173199985, 'completion_tokens_details': None, 'prompt_time': 0.010540565, 'prompt_tokens_details': None, 'queue_time': 0.047358915, 'total_time': 0.18374055}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d4335-5752-7810-a10a-376fb37b1aa6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 52, 'total_tokens': 98})

# %%
config1={"configurable":{'session_id':"chat2"}}

# %%
response=with_message_history.invoke(
    [HumanMessage(content="hey what is my name")],
    config=config1
)

# %%
response.content
# Out:
# "I'm happy to chat with you, but I don't have any information about your name. I'm a large language model, I don't have personal relationships or access to personal information about individuals. Each time you interact with me, it's a new conversation and I don't retain any information from previous conversations.\n\nIf you'd like to share your name with me, I'd be happy to chat with you and address you by name. Or, if you'd prefer, we can stick to a more general greeting. Let me know what you're comfortable with!"

# %% [markdown]
# ### promt templates

# %%
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","your are a helpful assistant, answer all the questions to the best of your ability"),
        MessagesPlaceholder(variable_name="messages")
    ]
)
chain=prompt|model

# %%
response=chain.invoke({"messages":[HumanMessage(content="hey my name is himesh")]})

# %%
response.content
# Out:
# 'Nice to meet you, Himesh! How can I assist you today?'
