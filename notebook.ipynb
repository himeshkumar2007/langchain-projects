# %%
from langchain_community.document_loaders import TextLoader
loder=TextLoader('')
# Out:
# c:\Users\Lenovo\Desktop\langchain\venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from langchain_community.document_loaders import PyPDFLoader
loder= PyPDFLoader('ShoeMorph_Research_Paper.pdf')
docs=loder.load()

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
textsplitter =RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
finaldocument=textsplitter.split_documents(docs)
finaldocument
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'TeX', 'creationdate': '2026-03-20T18:18:49+00:00', 'moddate': '2026-03-20T18:18:49+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'trapped': '/False', 'source': 'ShoeMorph_Research_Paper.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='ShoeMorph: Exploring Classical Computer Vision Techniques for\nAsymmetry-Aware Foot Size Estimation\nAkshat Bari 1, Ayush Kumar Maheshwari 2, Himesh Kumar 3\n1,2,3 Department of Computer Science,\n1,2,3 Poornima Institute of Engineering and Technology, Jaipur, India\nEmails: 12022pietcsakshat009@poornima.org, 22022pietcsayush041@poornima.org,\n32022pietcshimesh071@poornima.org\nAbstract\nThe paper introduces a minimalist and explainable computer vision based method to estimate the size'),
# ...

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embedding=(
    OllamaEmbeddings(model='nomic-embed-text-v2-moe')
)

# %%
r1=embedding.embed_query('hey how are you')

# %%
r1
# Out:
# [1.073324203491211,
#  0.41359958052635193,
#  -0.3272790312767029,
#  0.7623838186264038,
#  0.04863784462213516,
#  -0.39251384139060974,
#  0.6513756513595581,
#  0.03382550925016403,
#  -0.18636831641197205,
#  0.4357663094997406,
#  0.2595987319946289,
#  -1.0327281951904297,
#  1.526703119277954,
#  0.35222259163856506,
#  -0.06018234044313431,
#  1.0328344106674194,
#  0.025341836735606194,
#  0.764668345451355,
#  -0.3292413353919983,
#  0.9943559169769287,
#  1.1035845279693604,
#  -0.9677462577819824,
#  0.05032387375831604,
#  -0.19930502772331238,
#  0.2063172459602356,
#  -0.48558327555656433,
#  0.36573266983032227,
#  0.6115178465843201,
#  0.49427857995033264,
#  0.21474589407444,
#  0.07068369537591934,
#  0.1787419468164444,
#  0.6646662950515747,
#  0.3682844638824463,
#  -0.49209243059158325,
#  0.7366220355033875,
#  -0.12128625810146332,
#  -0.8398066163063049,
#  0.4830482006072998,
#  0.6310221552848816,
#  0.4093957841396332,
#  1.0398722887039185,
# ...

# %%
len(r1)
# Out:
# 768
